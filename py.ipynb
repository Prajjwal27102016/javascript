# %%
import turtle #importing library
window = turtle.Screen()
window.bgcolor("light blue") #screen background color
window.title("Turtle square")
pen = turtle.Turtle()
for i in range(2):
    pen.forward(100)
    pen.left(90)

window.exitonclick()

# %%
import pandas as pd

mydata={
    'cars': ['Toyota', 'Honda', 'Ford', 'BMW', 'Audi', 'Chevrolet', 'Nissan', 'Hyundai', 'Kia', 'Mazda', 'Subaru', 'Volkswagen', 'Mercedes', 'Lexus', 'Jeep', 'Dodge', 'Ram', 'GMC', 'Cadillac', 'Chrysler', 'Buick', 'Acura', 'Infiniti', 'Lincoln', 'Volvo', 'Mini', 'Fiat', 'Alfa Romeo', 'Mitsubishi', 'Suzuki', 'Saab', 'Pontiac', 'Hummer', 'Scion', 'Smart', 'Genesis', 'Rivian', 'Lucid', 'Polestar', 'Tata', 'Mahindra', 'Proton', 'Perodua', 'Great Wall', 'Chery', 'Geely', 'BYD', 'NIO', 'XPeng', 'Li Auto', 'Canoo', 'Fisker'],
    'speed': [120, 130, 125, 150, 160, 140, 135, 128, 132, 138, 145, 155, 165, 170, 142, 148, 152, 158, 162, 168, 175, 180, 185, 190, 195, 200, 205, 210, 215, 220, 225, 230, 235, 240, 245, 250, 255, 260, 265, 270, 275, 280, 285, 290, 295, 300,270, 275, 280, 285, 290, 295],
}
df = pd.DataFrame(mydata)
print(df)
# Out:
#           cars  speed
# 0       Toyota    120
# 1        Honda    130
# 2         Ford    125
# 3          BMW    150
# 4         Audi    160
# 5    Chevrolet    140
# 6       Nissan    135
# 7      Hyundai    128
# 8          Kia    132
# 9        Mazda    138
# 10      Subaru    145
# 11  Volkswagen    155
# 12    Mercedes    165
# 13       Lexus    170
# 14        Jeep    142
# 15       Dodge    148
# 16         Ram    152
# 17         GMC    158
# 18    Cadillac    162
# 19    Chrysler    168
# 20       Buick    175
# 21       Acura    180
# 22    Infiniti    185
# 23     Lincoln    190
# 24       Volvo    195
# 25        Mini    200
# 26        Fiat    205
# 27  Alfa Romeo    210
# 28  Mitsubishi    215
# 29      Suzuki    220
# 30        Saab    225
# 31     Pontiac    230
# 32      Hummer    235
# 33       Scion    240
# 34       Smart    245
# 35     Genesis    250
# 36      Rivian    255
# 37       Lucid    260
# 38    Polestar    265
# 39        Tata    270
# 40    Mahindra    275
# 41      Proton    280
# 42     Perodua    285
# 43  Great Wall    290
# 44       Chery    295
# 45       Geely    300
# 46         BYD    270
# 47         NIO    275
# 48       XPeng    280
# 49     Li Auto    285
# 50       Canoo    290
# 51      Fisker    295

# %%
list1 = ['bajaj', 'hero', 'tvs', 'yamaha', 'suzuki']
df1 = pd.Series(list1, index=['a', 'b', 'c', 'd', 'e'])
print(df1)
list2 = [1, 2, 3, 4, 5]
df2 = pd.Series(list2, index = ['a', 'b', 'c', 'd', 'e'])
print(df2)
# Out:
# a     bajaj
# b      hero
# c       tvs
# d    yamaha
# e    suzuki
# dtype: object
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
ydata = {
    'cars': ['Toyota', 'Honda', 'Ford', 'BMW', 'Audi', 'Chevrolet', 'Nissan', 'Hyundai', 'Kia', 'Mazda', 'Subaru', 'Volkswagen', 'Mercedes', 'Lexus', 'Jeep', 'Dodge', 'Ram', 'GMC', 'Cadillac', 'Chrysler', 'Buick', 'Acura', 'Infiniti', 'Lincoln', 'Volvo', 'Mini', 'Fiat', 'Alfa Romeo', 'Mitsubishi', 'Suzuki', 'Saab', 'Pontiac', 'Hummer', 'Scion', 'Smart', 'Genesis', 'Rivian', 'Lucid', 'Polestar', 'Tata', 'Mahindra', 'Proton', 'Perodua', 'Great Wall', 'Chery', 'Geely', 'BYD', 'NIO', 'XPeng', 'Li Auto', 'Canoo', 'Fisker'],
    'speed': [120, 130, 125, 150, 160, 140, 135, 128, 132, 138, 145, 155, 165, 170, 142, 148, 152, 158, 162, 168, 175, 180, 185, 190, 195, 200, 205, 210, 215, 220, 225, 230, 235, 240, 245, 250, 255, 260, 265, 270, 275, 280, 285, 290, 295, 300, 270, 275, 280, 285, 290, 295]
}
list1 = [x for x in range(1, 53)]
df1 = pd.DataFrame(ydata, list1)

print(df1)
# Out:
#           cars  speed
# 1       Toyota    120
# 2        Honda    130
# 3         Ford    125
# 4          BMW    150
# 5         Audi    160
# 6    Chevrolet    140
# 7       Nissan    135
# 8      Hyundai    128
# 9          Kia    132
# 10       Mazda    138
# 11      Subaru    145
# 12  Volkswagen    155
# 13    Mercedes    165
# 14       Lexus    170
# 15        Jeep    142
# 16       Dodge    148
# 17         Ram    152
# 18         GMC    158
# 19    Cadillac    162
# 20    Chrysler    168
# 21       Buick    175
# 22       Acura    180
# 23    Infiniti    185
# 24     Lincoln    190
# 25       Volvo    195
# 26        Mini    200
# 27        Fiat    205
# 28  Alfa Romeo    210
# 29  Mitsubishi    215
# 30      Suzuki    220
# 31        Saab    225
# 32     Pontiac    230
# 33      Hummer    235
# 34       Scion    240
# 35       Smart    245
# 36     Genesis    250
# 37      Rivian    255
# 38       Lucid    260
# 39    Polestar    265
# 40        Tata    270
# 41    Mahindra    275
# 42      Proton    280
# 43     Perodua    285
# 44  Great Wall    290
# 45       Chery    295
# 46       Geely    300
# 47         BYD    270
# 48         NIO    275
# 49       XPeng    280
# 50     Li Auto    285
# 51       Canoo    290
# 52      Fisker    295

# %%
df1.loc[1:10]
# Out:
#          cars  speed
# 1      Toyota    120
# 2       Honda    130
# 3        Ford    125
# 4         BMW    150
# 5        Audi    160
# 6   Chevrolet    140
# 7      Nissan    135
# 8     Hyundai    128
# 9         Kia    132
# 10      Mazda    138

# %%
from rich import print
